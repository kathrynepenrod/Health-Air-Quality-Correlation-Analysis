# %%
import numpy as np 

import pandas as pd 

import scipy as sp 

from scipy import stats 

import matplotlib 

import sqlite3 

import matplotlib.pyplot as plt 

import seaborn as sns 

import sklearn 

from sklearn.preprocessing import StandardScaler 

from sklearn.decomposition import PCA 

import warnings 

import re 

warnings.filterwarnings('ignore')

# %%
#upload the data file 

air_df = pd.read_csv('Air_Quality.csv') 

conn=sqlite3.connect('Air_Quality.csv') 

#check that it was uploaded 

air_df.head(n = 3)
# Out:
#    Unique ID  Indicator ID                    Name Measure Measure Info  \
# 0     336867           375  Nitrogen dioxide (NO2)    Mean          ppb
# 1     336741           375  Nitrogen dioxide (NO2)    Mean          ppb
# 2     550157           375  Nitrogen dioxide (NO2)    Mean          ppb
#
#   Geo Type Name  Geo Join ID                     Geo Place Name  \
# 0            CD          407      Flushing and Whitestone (CD7)
# 1            CD          107              Upper West Side (CD7)
# 2            CD          414  Rockaway and Broad Channel (CD14)
#
#            Time Period  Start_Date  Data Value  Message
# 0       Winter 2014-15  12/01/2014       23.97      NaN
# 1       Winter 2014-15  12/01/2014       27.42      NaN
# 2  Annual Average 2017  01/01/2017       12.55      NaN

# %%
#check the column names 

air_df.columns
# Out:
# Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Geo Place Name', 'Time Period',
#        'Start_Date', 'Data Value', 'Message'],
#       dtype='object')

# %%
#Change data types 

air_df['Unique ID'].apply(int) 

air_df['Indicator ID'].apply(int) 

air_df['Name'].apply(str) 

air_df['Measure'].apply(str) 

air_df['Measure Info'].apply(str) 

air_df['Geo Type Name'].apply(str) 

air_df['Geo Join ID'].apply(int) 

air_df['Geo Place Name'].apply(str) 

air_df['Time Period'].apply(str) 

air_df['Start_Date'].apply(str) 

air_df['Data Value'].apply(float)
# Out:
# 0        23.97
# 1        27.42
# 2        12.55
# 3        22.63
# 4        14.00
#          ...
# 18857    25.78
# 18858    28.13
# 18859    28.78
# 18860    23.68
# 18861    23.77
# Name: Data Value, Length: 18862, dtype: float64

# %%
#look for invalid values 

invalidmask = air_df.astype(str).applymap(lambda x: bool(re.search(r'[^ -~]', x))) 

dirty_rows=air_df[invalidmask.any(axis=1)]
print(dirty_rows)
# Out:
#        Unique ID  Indicator ID                               Name  \
# 7546      799850           647  Outdoor Air Toxics - Formaldehyde
# 7547      315663           647  Outdoor Air Toxics - Formaldehyde
# 7548      315673           647  Outdoor Air Toxics - Formaldehyde
# 7549      130767           647  Outdoor Air Toxics - Formaldehyde
# 7550      130739           647  Outdoor Air Toxics - Formaldehyde
# ...          ...           ...                                ...
# 18685     130764           647  Outdoor Air Toxics - Formaldehyde
# 18686     799867           647  Outdoor Air Toxics - Formaldehyde
# 18687     315641           647  Outdoor Air Toxics - Formaldehyde
# 18777     130780           647  Outdoor Air Toxics - Formaldehyde
# 18778     227527           647  Outdoor Air Toxics - Formaldehyde
#
#                             Measure Measure Info Geo Type Name  Geo Join ID  \
# 7546   Annual average concentration       Âµg/m3         UHF42          408
# 7547   Annual average concentration       Âµg/m3         UHF42          308
# 7548   Annual average concentration       Âµg/m3         UHF42          408
# 7549   Annual average concentration       Âµg/m3         UHF42          407
# 7550   Annual average concentration       Âµg/m3         UHF42          107
# ...                             ...          ...           ...          ...
# 18685  Annual average concentration       Âµg/m3         UHF42          404
# 18686  Annual average concentration       Âµg/m3       Borough            5
# 18687  Annual average concentration       Âµg/m3         UHF42          104
# 18777  Annual average concentration       Âµg/m3       Borough            5
# 18778  Annual average concentration       Âµg/m3            CD          207
#
#                               Geo Place Name Time Period  Start_Date  \
# 7546                                 Jamaica        2014  01/01/2014
# 7547                Greenwich Village - SoHo        2011  01/01/2011
# 7548                                 Jamaica        2011  01/01/2011
# 7549                        Southwest Queens        2005  01/01/2005
# 7550                Hunts Point - Mott Haven        2005  01/01/2005
# ...                                      ...         ...         ...
# 18685                  Bayside - Little Neck        2005  01/01/2005
# 18686                          Staten Island        2014  01/01/2014
# 18687                   Pelham - Throgs Neck        2011  01/01/2011
# 18777                          Staten Island        2005  01/01/2005
# 18778  Kingsbridge Heights and Bedford (CD7)        2011  01/01/2011
#
#        Data Value  Message
# 7546     1.376573      NaN
# 7547     2.600000      NaN
# 7548     1.900000      NaN
# 7549     2.400000      NaN
# 7550     3.500000      NaN
# ...           ...      ...
# 18685    2.500000      NaN
# 18686    1.283186      NaN
# 18687    2.000000      NaN
# 18777    2.300000      NaN
# 18778    2.200000      NaN
#
# [406 rows x 12 columns]

# %%
#drop duplicates & locate empty cells 

clean_df = air_df.drop_duplicates(subset= 

['Indicator ID', 'Geo Place Name', 'Time Period', 'Data Value']) 

clean_df.isna().sum()
# Out:
# Unique ID             0
# Indicator ID          0
# Name                  0
# Measure               0
# Measure Info          0
# Geo Type Name         0
# Geo Join ID           0
# Geo Place Name        0
# Time Period           0
# Start_Date            0
# Data Value            0
# Message           16302
# dtype: int64

# %%
#look at the data with less noise 

clean_df=clean_df.drop(columns=[ 

'Unique ID','Indicator ID','Message','Geo Join ID','Start_Date','Geo Type Name', 'Measure', 'Measure Info']) 

        

        #Remaining columns: 

        ##'Name', 'Geo Place Name', 'Time Period', 'Data Value'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4324\456898502.py in <module>
#       1 #look at the data with less noise
#       2
# ----> 3 clean_df=clean_df.drop(columns=[
#       4
#       5 'Unique ID','Indicator ID','Message','Geo Join ID','Start_Date','Geo Type Name', 'Measure', 'Measure Info'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['Unique ID', 'Indicator ID', 'Message', 'Geo Join ID', 'Start_Date', 'Geo Type Name', 'Measure', 'Measure Info'] not found in axis"

# %%
clean_df.head(5)
# Out:
#                      Name                     Geo Place Name  \
# 0  Nitrogen dioxide (NO2)      Flushing and Whitestone (CD7)
# 1  Nitrogen dioxide (NO2)              Upper West Side (CD7)
# 2  Nitrogen dioxide (NO2)  Rockaway and Broad Channel (CD14)
# 3  Nitrogen dioxide (NO2)      Flushing and Whitestone (CD7)
# 4  Nitrogen dioxide (NO2)      Flushing and Whitestone (CD7)
#
#            Time Period  Data Value
# 0       Winter 2014-15       23.97
# 1       Winter 2014-15       27.42
# 2  Annual Average 2017       12.55
# 3       Winter 2015-16       22.63
# 4          Summer 2016       14.00

# %%
##Time to make separate dataframes so I can examine trends more closely 

##PM2.5 examination 

#Asthma emergency department visits due to PM2.5 

#asthma_df 

asthma_df= clean_df [clean_df ["Name"] == "Asthma emergency department visits due to PM2.5"] 
 

#Deaths due to PM2.5 

#death_df 

death_df= clean_df [clean_df ["Name"] == "Deaths due to PM2.5"] 

 

#Fine particles (PM 2.5) 

#pm_df 

pm_df= clean_df [clean_df["Name"] == "Fine particles (PM 2.5)"] 

 

#Cardiovascular hospitalizations due to PM2.5 (age 40+) 

#cardio_df 

cardio_df= clean_df [clean_df ["Name"] == "Cardiovascular hospitalizations due to PM2.5 (age 40+)"] 

 

#Respiratory hospitalizations due to PM2.5 (age 20+) 

#resp_df 

resp_df= clean_df [clean_df ["Name"] == "Respiratory hospitalizations due to PM2.5 (age 20+)"] 

 

#pm25_all 

pm25_all= clean_df [clean_df ["Name"].isin(["Respiratory hospitalizations due to PM2.5 (age 20+)","Cardiovascular hospitalizations due to PM2.5 (age 40+)","Fine particles (PM 2.5)","Deaths due to PM2.5", "Asthma emergency department visits due to PM2.5"])]

# %%
#use df.describe() 

#asthma_df.describe() 

#cardio_df.describe() 

#death_df.describe() 

#pm_df.describe() 

#resp_df.describe() 

#pm25_all.describe()
# Out:
#         Data Value
# count  6466.000000
# mean     15.116080
# std      23.263027
# min       2.000000
# 25%       7.688777
# 50%       9.330000
# 75%      11.740000
# max     424.700000

# %%
#Use this to check possible outliers 

#asthma_df[asthma_df['Data Value'] > 250].sort_values(by='Geo Place Name')

#cardio_df[cardio_df['Data Value'] > 30].sort_values(by='Geo Place Name')

#death_df[death_df['Data Value'] > 75].sort_values(by='Geo Place Name')

#pm_df[pm_df['Data Value'] > 15.5].sort_values(by='Geo Place Name')

#resp_df[resp_df['Data Value'] > 20].sort_values(by='Geo Place Name')

# %%
#Compare # of entries of certain variables with other variables 

pd.crosstab(pm25_all 

['Name' 

], pm25_all  

['Geo Place Name' 

])
# Out:
# Geo Place Name                                      Bay Ridge and Dyker Heights (CD10)  \
# Name
# Asthma emergency department visits due to PM2.5                                      0
# Cardiovascular hospitalizations due to PM2.5 (a...                                   0
# Deaths due to PM2.5                                                                  0
# Fine particles (PM 2.5)                                                             45
# Respiratory hospitalizations due to PM2.5 (age ...                                   0
#
# Geo Place Name                                      Bayside - Little Neck  \
# Name
# Asthma emergency department visits due to PM2.5                        10
# Cardiovascular hospitalizations due to PM2.5 (a...                      5
# Deaths due to PM2.5                                                     5
# Fine particles (PM 2.5)                                                45
# Respiratory hospitalizations due to PM2.5 (age ...                      5
#
# Geo Place Name                                      Bayside Little Neck-Fresh Meadows  \
# Name
# Asthma emergency department visits due to PM2.5                                     0
# Cardiovascular hospitalizations due to PM2.5 (a...                                  0
# Deaths due to PM2.5                                                                 0
# Fine particles (PM 2.5)                                                            45
# Respiratory hospitalizations due to PM2.5 (age ...                                  0
#
# Geo Place Name                                      Bayside and Little Neck (CD11)  \
# Name
# Asthma emergency department visits due to PM2.5                                  0
# Cardiovascular hospitalizations due to PM2.5 (a...                               0
# Deaths due to PM2.5                                                              0
# Fine particles (PM 2.5)                                                         45
# Respiratory hospitalizations due to PM2.5 (age ...                               0
#
# Geo Place Name                                      Bedford Stuyvesant (CD3)  \
# Name
# Asthma emergency department visits due to PM2.5                            0
# Cardiovascular hospitalizations due to PM2.5 (a...                         0
# Deaths due to PM2.5                                                        0
# Fine particles (PM 2.5)                                                   45
# Respiratory hospitalizations due to PM2.5 (age ...                         0
#
# Geo Place Name                                      Bedford Stuyvesant - Crown Heights  \
# Name
# Asthma emergency department visits due to PM2.5                                     10
# Cardiovascular hospitalizations due to PM2.5 (a...                                   5
# Deaths due to PM2.5                                                                  5
# Fine particles (PM 2.5)                                                             45
# Respiratory hospitalizations due to PM2.5 (age ...                                   5
#
# Geo Place Name                                      Belmont and East Tremont (CD6)  \
# Name
# Asthma emergency department visits due to PM2.5                                  0
# Cardiovascular hospitalizations due to PM2.5 (a...                               0
# Deaths due to PM2.5                                                              0
# Fine particles (PM 2.5)                                                         45
# Respiratory hospitalizations due to PM2.5 (age ...                               0
#
# Geo Place Name                                      Bensonhurst (CD11)  \
# Name
# Asthma emergency department visits due to PM2.5                      0
# Cardiovascular hospitalizations due to PM2.5 (a...                   0
# Deaths due to PM2.5                                                  0
# Fine particles (PM 2.5)                                             45
# Respiratory hospitalizations due to PM2.5 (age ...                   0
#
# Geo Place Name                                      Bensonhurst - Bay Ridge  \
# Name
# Asthma emergency department visits due to PM2.5                          10
# Cardiovascular hospitalizations due to PM2.5 (a...                        5
# Deaths due to PM2.5                                                       5
# Fine particles (PM 2.5)                                                  45
# Respiratory hospitalizations due to PM2.5 (age ...                        5
#
# Geo Place Name                                      Borough Park  ...  \
# Name                                                              ...
# Asthma emergency department visits due to PM2.5               10  ...
# Cardiovascular hospitalizations due to PM2.5 (a...             5  ...
# Deaths due to PM2.5                                            5  ...
# Fine particles (PM 2.5)                                       45  ...
# Respiratory hospitalizations due to PM2.5 (age ...             5  ...
#
# Geo Place Name                                      Upper East Side-Gramercy  \
# Name
# Asthma emergency department visits due to PM2.5                            0
# Cardiovascular hospitalizations due to PM2.5 (a...                         0
# Deaths due to PM2.5                                                        0
# Fine particles (PM 2.5)                                                   45
# Respiratory hospitalizations due to PM2.5 (age ...                         0
#
# Geo Place Name                                      Upper West Side  \
# Name
# Asthma emergency department visits due to PM2.5                  10
# Cardiovascular hospitalizations due to PM2.5 (a...                5
# Deaths due to PM2.5                                               5
# Fine particles (PM 2.5)                                          54
# Respiratory hospitalizations due to PM2.5 (age ...                5
#
# Geo Place Name                                      Upper West Side (CD7)  \
# Name
# Asthma emergency department visits due to PM2.5                         0
# Cardiovascular hospitalizations due to PM2.5 (a...                      0
# Deaths due to PM2.5                                                     0
# Fine particles (PM 2.5)                                                45
# Respiratory hospitalizations due to PM2.5 (age ...                      0
#
# Geo Place Name                                      Washington Heights  \
# Name
# Asthma emergency department visits due to PM2.5                     10
# Cardiovascular hospitalizations due to PM2.5 (a...                   5
# Deaths due to PM2.5                                                  5
# Fine particles (PM 2.5)                                             66
# Respiratory hospitalizations due to PM2.5 (age ...                   5
#
# Geo Place Name                                      Washington Heights and Inwood (CD12)  \
# Name
# Asthma emergency department visits due to PM2.5                                        0
# Cardiovascular hospitalizations due to PM2.5 (a...                                     0
# Deaths due to PM2.5                                                                    0
# Fine particles (PM 2.5)                                                               45
# Respiratory hospitalizations due to PM2.5 (age ...                                     0
#
# Geo Place Name                                      West Queens  \
# Name
# Asthma emergency department visits due to PM2.5              10
# Cardiovascular hospitalizations due to PM2.5 (a...            5
# Deaths due to PM2.5                                           5
# Fine particles (PM 2.5)                                      46
# Respiratory hospitalizations due to PM2.5 (age ...            5
#
# Geo Place Name                                      Williamsbridge and Baychester (CD12)  \
# Name
# Asthma emergency department visits due to PM2.5                                        0
# Cardiovascular hospitalizations due to PM2.5 (a...                                     0
# Deaths due to PM2.5                                                                    0
# Fine particles (PM 2.5)                                                               45
# Respiratory hospitalizations due to PM2.5 (age ...                                     0
#
# Geo Place Name                                      Williamsburg - Bushwick  \
# Name
# Asthma emergency department visits due to PM2.5                          10
# Cardiovascular hospitalizations due to PM2.5 (a...                        5
# Deaths due to PM2.5                                                       5
# Fine particles (PM 2.5)                                                  57
# Respiratory hospitalizations due to PM2.5 (age ...                        5
#
# Geo Place Name                                      Willowbrook  \
# Name
# Asthma emergency department visits due to PM2.5              10
# Cardiovascular hospitalizations due to PM2.5 (a...            5
# Deaths due to PM2.5                                           5
# Fine particles (PM 2.5)                                      45
# Respiratory hospitalizations due to PM2.5 (age ...            5
#
# Geo Place Name                                      Woodside and Sunnyside (CD2)
# Name
# Asthma emergency department visits due to PM2.5                                0
# Cardiovascular hospitalizations due to PM2.5 (a...                             0
# Deaths due to PM2.5                                                            0
# Fine particles (PM 2.5)                                                       45
# Respiratory hospitalizations due to PM2.5 (age ...                             0
#
# [5 rows x 114 columns]

# %%
#examine specific regions 
bayside_little_neck= pm25_all [pm25_all ['Geo Place Name'].isin(['Bayside - Little Neck'])].sort_values(by='Time Period')
little_neck=bayside_little_neck.style.set_caption("Bayside - Little Neck") 
little_neck
# Out:
# <style type="text/css">
# </style>
# <table id="T_93b1e">
#   <caption>Bayside - Little Neck</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93b1e_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_93b1e_level0_col1" class="col_heading level0 col1" >Geo Place Name</th>
#       <th id="T_93b1e_level0_col2" class="col_heading level0 col2" >Time Period</th>
#       <th id="T_93b1e_level0_col3" class="col_heading level0 col3" >Data Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93b1e_level0_row0" class="row_heading level0 row0" >5728</th>
#       <td id="T_93b1e_row0_col0" class="data row0 col0" >Respiratory hospitalizations due to PM2.5 (age 20+)</td>
#       <td id="T_93b1e_row0_col1" class="data row0 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row0_col2" class="data row0 col2" >2005-2007</td>
#       <td id="T_93b1e_row0_col3" class="data row0 col3" >15.100000</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row1" class="row_heading level0 row1" >18743</th>
#       <td id="T_93b1e_row1_col0" class="data row1 col0" >Deaths due to PM2.5</td>
#       <td id="T_93b1e_row1_col1" class="data row1 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row1_col2" class="data row1 col2" >2005-2007</td>
#       <td id="T_93b1e_row1_col3" class="data row1 col3" >48.900000</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row2" class="row_heading level0 row2" >18459</th>
#       <td id="T_93b1e_row2_col0" class="data row2 col0" >Cardiovascular hospitalizations due to PM2.5 (age 40+)</td>
#       <td id="T_93b1e_row2_col1" class="data row2 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row2_col2" class="data row2 col2" >2005-2007</td>
#       <td id="T_93b1e_row2_col3" class="data row2 col3" >18.300000</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row3" class="row_heading level0 row3" >11463</th>
#       <td id="T_93b1e_row3_col0" class="data row3 col0" >Asthma emergency department visits due to PM2.5</td>
#       <td id="T_93b1e_row3_col1" class="data row3 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row3_col2" class="data row3 col2" >2005-2007</td>
#       <td id="T_93b1e_row3_col3" class="data row3 col3" >26.700000</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row4" class="row_heading level0 row4" >11732</th>
#       <td id="T_93b1e_row4_col0" class="data row4 col0" >Asthma emergency department visits due to PM2.5</td>
#       <td id="T_93b1e_row4_col1" class="data row4 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row4_col2" class="data row4 col2" >2005-2007</td>
#       <td id="T_93b1e_row4_col3" class="data row4 col3" >8.500000</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row5" class="row_heading level0 row5" >10371</th>
#       <td id="T_93b1e_row5_col0" class="data row5 col0" >Asthma emergency department visits due to PM2.5</td>
#       <td id="T_93b1e_row5_col1" class="data row5 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row5_col2" class="data row5 col2" >2009-2011</td>
#       <td id="T_93b1e_row5_col3" class="data row5 col3" >6.700000</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row6" class="row_heading level0 row6" >5727</th>
#       <td id="T_93b1e_row6_col0" class="data row6 col0" >Respiratory hospitalizations due to PM2.5 (age 20+)</td>
#       <td id="T_93b1e_row6_col1" class="data row6 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row6_col2" class="data row6 col2" >2009-2011</td>
#       <td id="T_93b1e_row6_col3" class="data row6 col3" >10.200000</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row7" class="row_heading level0 row7" >14130</th>
#       <td id="T_93b1e_row7_col0" class="data row7 col0" >Cardiovascular hospitalizations due to PM2.5 (age 40+)</td>
#       <td id="T_93b1e_row7_col1" class="data row7 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row7_col2" class="data row7 col2" >2009-2011</td>
#       <td id="T_93b1e_row7_col3" class="data row7 col3" >12.500000</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row8" class="row_heading level0 row8" >13738</th>
#       <td id="T_93b1e_row8_col0" class="data row8 col0" >Asthma emergency department visits due to PM2.5</td>
#       <td id="T_93b1e_row8_col1" class="data row8 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row8_col2" class="data row8 col2" >2009-2011</td>
#       <td id="T_93b1e_row8_col3" class="data row8 col3" >22.100000</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row9" class="row_heading level0 row9" >14095</th>
#       <td id="T_93b1e_row9_col0" class="data row9 col0" >Deaths due to PM2.5</td>
#       <td id="T_93b1e_row9_col1" class="data row9 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row9_col2" class="data row9 col2" >2009-2011</td>
#       <td id="T_93b1e_row9_col3" class="data row9 col3" >34.500000</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row10" class="row_heading level0 row10" >15559</th>
#       <td id="T_93b1e_row10_col0" class="data row10 col0" >Asthma emergency department visits due to PM2.5</td>
#       <td id="T_93b1e_row10_col1" class="data row10 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row10_col2" class="data row10 col2" >2012-2014</td>
#       <td id="T_93b1e_row10_col3" class="data row10 col3" >6.627942</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row11" class="row_heading level0 row11" >8650</th>
#       <td id="T_93b1e_row11_col0" class="data row11 col0" >Respiratory hospitalizations due to PM2.5 (age 20+)</td>
#       <td id="T_93b1e_row11_col1" class="data row11 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row11_col2" class="data row11 col2" >2012-2014</td>
#       <td id="T_93b1e_row11_col3" class="data row11 col3" >6.965867</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row12" class="row_heading level0 row12" >15934</th>
#       <td id="T_93b1e_row12_col0" class="data row12 col0" >Cardiovascular hospitalizations due to PM2.5 (age 40+)</td>
#       <td id="T_93b1e_row12_col1" class="data row12 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row12_col2" class="data row12 col2" >2012-2014</td>
#       <td id="T_93b1e_row12_col3" class="data row12 col3" >8.655824</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row13" class="row_heading level0 row13" >18711</th>
#       <td id="T_93b1e_row13_col0" class="data row13 col0" >Deaths due to PM2.5</td>
#       <td id="T_93b1e_row13_col1" class="data row13 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row13_col2" class="data row13 col2" >2012-2014</td>
#       <td id="T_93b1e_row13_col3" class="data row13 col3" >28.434109</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row14" class="row_heading level0 row14" >8629</th>
#       <td id="T_93b1e_row14_col0" class="data row14 col0" >Asthma emergency department visits due to PM2.5</td>
#       <td id="T_93b1e_row14_col1" class="data row14 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row14_col2" class="data row14 col2" >2012-2014</td>
#       <td id="T_93b1e_row14_col3" class="data row14 col3" >13.435123</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row15" class="row_heading level0 row15" >8630</th>
#       <td id="T_93b1e_row15_col0" class="data row15 col0" >Asthma emergency department visits due to PM2.5</td>
#       <td id="T_93b1e_row15_col1" class="data row15 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row15_col2" class="data row15 col2" >2015-2017</td>
#       <td id="T_93b1e_row15_col3" class="data row15 col3" >12.200000</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row16" class="row_heading level0 row16" >8651</th>
#       <td id="T_93b1e_row16_col0" class="data row16 col0" >Respiratory hospitalizations due to PM2.5 (age 20+)</td>
#       <td id="T_93b1e_row16_col1" class="data row16 col1" >Bayside - Little Neck</td>
#       <td id="T_93b1e_row16_col2" class="data row16 col2" >2015-2017</td>
#       <td id="T_93b1e_row16_col3" class="data row16 col3" >8.200000</td>
#     </tr>
#     <tr>
#       <th id="T_93b1e_level0_row17" class=

# %%
#make histogram to check for outliers 

#y axis is value counts, x is Data Value 

pm25_all.hist(column='Data Value', by='Name', bins=5, edgecolor='black', figsize=(10, 18), layout=(9,2))  

plt.suptitle("Data Values by Type", y=1.02)  

plt.subplots_adjust(hspace=0.8, wspace=0.4) 

plt.tight_layout() 

plt.show()

# %%
pm25_pivot = pm25_all.pivot_table( index=['Geo Place Name', 'Time Period'], columns='Name', values='Data Value' ) 
pm25_pivot.columns = pm25_pivot2.columns.str.strip() 
pm25_pivot
# Out:
# Name                                                    Asthma emergency department visits due to PM2.5  \
# Geo Place Name                     Time Period
# Bay Ridge and Dyker Heights (CD10) Annual Average 2009                                              NaN
#                                    Annual Average 2010                                              NaN
#                                    Annual Average 2011                                              NaN
#                                    Annual Average 2012                                              NaN
#                                    Annual Average 2013                                              NaN
# ...                                                                                                 ...
# Woodside and Sunnyside (CD2)       Winter 2018-19                                                   NaN
#                                    Winter 2019-20                                                   NaN
#                                    Winter 2020-21                                                   NaN
#                                    Winter 2021-22                                                   NaN
#                                    Winter 2022-23                                                   NaN
#
# Name                                                    Cardiovascular hospitalizations due to PM2.5 (age 40+)  \
# Geo Place Name                     Time Period
# Bay Ridge and Dyker Heights (CD10) Annual Average 2009                                                NaN
#                                    Annual Average 2010                                                NaN
#                                    Annual Average 2011                                                NaN
#                                    Annual Average 2012                                                NaN
#                                    Annual Average 2013                                                NaN
# ...                                                                                                   ...
# Woodside and Sunnyside (CD2)       Winter 2018-19                                                     NaN
#                                    Winter 2019-20                                                     NaN
#                                    Winter 2020-21                                                     NaN
#                                    Winter 2021-22                                                     NaN
#                                    Winter 2022-23                                                     NaN
#
# Name                                                    Deaths due to PM2.5  \
# Geo Place Name                     Time Period
# Bay Ridge and Dyker Heights (CD10) Annual Average 2009                  NaN
#                                    Annual Average 2010                  NaN
#                                    Annual Average 2011                  NaN
#                                    Annual Average 2012                  NaN
#                                    Annual Average 2013                  NaN
# ...                                                                     ...
# Woodside and Sunnyside (CD2)       Winter 2018-19                       NaN
#                                    Winter 2019-20                       NaN
#                                    Winter 2020-21                       NaN
#                                    Winter 2021-22                       NaN
#                                    Winter 2022-23                       NaN
#
# Name                                                    Fine particles (PM 2.5)  \
# Geo Place Name                     Time Period
# Bay Ridge and Dyker Heights (CD10) Annual Average 2009                10.180000
#                                    Annual Average 2010                 9.410000
#                                    Annual Average 2011                10.010000
#                                    Annual Average 2012                 8.810000
#                                    Annual Average 2013                 8.410000
# ...                                                                         ...
# Woodside and Sunnyside (CD2)       Winter 2018-19                      9.070000
#                                    Winter 2019-20                      8.430000
#                                    Winter 2020-21                      7.931445
#                                    Winter 2021-22                      7.313604
#                                    Winter 2022-23                      6.954335
#
# Name                                                    Respiratory hospitalizations due to PM2.5 (age 20+)
# Geo Place Name                     Time Period
# Bay Ridge and Dyker Heights (CD10) Annual Average 2009                                                NaN
#                                    Annual Average 2010                                                NaN
#                                    Annual Average 2011                                                NaN
#                                    Annual Average 2012                                                NaN
#                                    Annual Average 2013                                                NaN
# ...                                                                                                   ...
# Woodside and Sunnyside (CD2)       Winter 2018-19                                                     NaN
#                                    Winter 2019-20                                                     NaN
#                                    Winter 2020-21                                                     NaN
#                                    Winter 2021-22                                                     NaN
#                                    Winter 2022-23                                                     NaN
#
# [5370 rows x 5 columns]

# %%
#whisker box plot 

plt.figure(figsize=(6, 2)) 
sns.boxplot(data=asthma_df, x='Data Value', linewidth=0.9) 

plt.show()

# %%
sns.scatterplot(data = asthma_df, x = 'Data Value', 

                y = 'Time Period');

# %%
#scatter plot - asthma ER vs pm2.5 levels

asthma_df2 = asthma_df.rename(columns={"Data Value": "asthma_er_visits"})  

pm_df2 = pm_df.rename(columns={"Data Value": "pm25_levels"})  



merged_df = pd.merge(asthma_df2, pm_df2, on="Geo Place Name")  


plt.figure(figsize=(8, 6)) 
sns.scatterplot(data=merged_df, x="pm25_levels", y="asthma_er_visits") 



plt.title("PM2.5 Levels vs. Asthma ER Visits")  

plt.xlabel("PM2.5 Concentration") 
plt.ylabel("Asthma ER Visits")  

plt.grid(True, linestyle="--", alpha=0.7)  

plt.show()

# %%
asthma = asthma_df['Start_Date'].dt.year 

sns.lineplot(data = asthma_df, x = years, 

       y = 'Data Value', 

       estimator = np.mean);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Start_Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4324\3178084105.py in <module>
# ----> 1 asthma = asthma_df['Start_Date'].dt.year
#       2
#       3 sns.lineplot(data = asthma_df, x = years,
#       4
#       5        y = 'Data Value',
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Start_Date'
