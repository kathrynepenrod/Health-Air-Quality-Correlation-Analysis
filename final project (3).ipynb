# %%
import numpy as np 
import pandas as pd 
import scipy as sp 
from scipy import stats 
import matplotlib 
import sqlite3 
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn 
from sklearn.preprocessing import StandardScaler 
from sklearn.decomposition import PCA 
import warnings 
import re

# %%
#upload the data file 
air_df = pd.read_csv('Air_Quality.csv') 
conn=sqlite3.connect('Air_Quality.csv') 
#check that it was uploaded 
air_df.head(n = 3)
# Out:
#    Unique ID  Indicator ID                    Name Measure Measure Info  \
# 0     336867           375  Nitrogen dioxide (NO2)    Mean          ppb
# 1     336741           375  Nitrogen dioxide (NO2)    Mean          ppb
# 2     550157           375  Nitrogen dioxide (NO2)    Mean          ppb
#
#   Geo Type Name  Geo Join ID                     Geo Place Name  \
# 0            CD          407      Flushing and Whitestone (CD7)
# 1            CD          107              Upper West Side (CD7)
# 2            CD          414  Rockaway and Broad Channel (CD14)
#
#            Time Period  Start_Date  Data Value  Message
# 0       Winter 2014-15  12/01/2014       23.97      NaN
# 1       Winter 2014-15  12/01/2014       27.42      NaN
# 2  Annual Average 2017  01/01/2017       12.55      NaN

# %%
#check the column names 
air_df.columns
# Out:
# Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Geo Place Name', 'Time Period',
#        'Start_Date', 'Data Value', 'Message'],
#       dtype='object')

# %%
#Change data types 
air_df['Unique ID'].apply(int) 
air_df['Indicator ID'].apply(int) 
air_df['Name'].apply(str) 
air_df['Measure'].apply(str) 
air_df['Measure Info'].apply(str) 
air_df['Geo Type Name'].apply(str) 
air_df['Geo Join ID'].apply(int) 
air_df['Geo Place Name'].apply(str) 
air_df['Time Period'].apply(str) 
air_df['Data Value'].apply(float)
# Out:
# 0        23.97
# 1        27.42
# 2        12.55
# 3        22.63
# 4        14.00
#          ...
# 18857    25.78
# 18858    28.13
# 18859    28.78
# 18860    23.68
# 18861    23.77
# Name: Data Value, Length: 18862, dtype: float64

# %%
#convert start_date column to date format
#may need to do this for every new dataframe as needed - need to test
air_df['Start_Date'] = pd.to_datetime(air_df['Start_Date'])

# %%
#look for invalid values 
invalidmask = air_df.astype(str).applymap(lambda x: bool(re.search(r'[^ -~]', x))) 
dirty_rows=air_df[invalidmask.any(axis=1)]
print(dirty_rows)
# Out:
#        Unique ID  Indicator ID                               Name  \
# 7546      799850           647  Outdoor Air Toxics - Formaldehyde
# 7547      315663           647  Outdoor Air Toxics - Formaldehyde
# 7548      315673           647  Outdoor Air Toxics - Formaldehyde
# 7549      130767           647  Outdoor Air Toxics - Formaldehyde
# 7550      130739           647  Outdoor Air Toxics - Formaldehyde
# ...          ...           ...                                ...
# 18685     130764           647  Outdoor Air Toxics - Formaldehyde
# 18686     799867           647  Outdoor Air Toxics - Formaldehyde
# 18687     315641           647  Outdoor Air Toxics - Formaldehyde
# 18777     130780           647  Outdoor Air Toxics - Formaldehyde
# 18778     227527           647  Outdoor Air Toxics - Formaldehyde
#
#                             Measure Measure Info Geo Type Name  Geo Join ID  \
# 7546   Annual average concentration       Âµg/m3         UHF42          408
# 7547   Annual average concentration       Âµg/m3         UHF42          308
# 7548   Annual average concentration       Âµg/m3         UHF42          408
# 7549   Annual average concentration       Âµg/m3         UHF42          407
# 7550   Annual average concentration       Âµg/m3         UHF42          107
# ...                             ...          ...           ...          ...
# 18685  Annual average concentration       Âµg/m3         UHF42          404
# 18686  Annual average concentration       Âµg/m3       Borough            5
# 18687  Annual average concentration       Âµg/m3         UHF42          104
# 18777  Annual average concentration       Âµg/m3       Borough            5
# 18778  Annual average concentration       Âµg/m3            CD          207
#
#                               Geo Place Name Time Period Start_Date  \
# 7546                                 Jamaica        2014 2014-01-01
# 7547                Greenwich Village - SoHo        2011 2011-01-01
# 7548                                 Jamaica        2011 2011-01-01
# 7549                        Southwest Queens        2005 2005-01-01
# 7550                Hunts Point - Mott Haven        2005 2005-01-01
# ...                                      ...         ...        ...
# 18685                  Bayside - Little Neck        2005 2005-01-01
# 18686                          Staten Island        2014 2014-01-01
# 18687                   Pelham - Throgs Neck        2011 2011-01-01
# 18777                          Staten Island        2005 2005-01-01
# 18778  Kingsbridge Heights and Bedford (CD7)        2011 2011-01-01
#
#        Data Value  Message
# 7546     1.376573      NaN
# 7547     2.600000      NaN
# 7548     1.900000      NaN
# 7549     2.400000      NaN
# 7550     3.500000      NaN
# ...           ...      ...
# 18685    2.500000      NaN
# 18686    1.283186      NaN
# 18687    2.000000      NaN
# 18777    2.300000      NaN
# 18778    2.200000      NaN
#
# [406 rows x 12 columns]

# %%
#drop duplicates & locate empty cells 
clean_df = air_df.drop_duplicates(subset= 
['Indicator ID', 'Geo Place Name', 'Time Period', 'Data Value']) 
clean_df.isna().sum()
# Out:
# Unique ID             0
# Indicator ID          0
# Name                  0
# Measure               0
# Measure Info          0
# Geo Type Name         0
# Geo Join ID           0
# Geo Place Name        0
# Time Period           0
# Start_Date            0
# Data Value            0
# Message           16302
# dtype: int64

# %%
#look at the data with less noise 
clean_df=clean_df.drop(columns=[ 
'Unique ID','Indicator ID','Message','Geo Join ID','Geo Type Name', 'Measure', 'Measure Info']) 
        #Remaining columns: 
        ##'Name', 'Geo Place Name', 'Time Period', 'Data Value', 'Start_Date'
clean_df.head(5)
# Out:
#                      Name                     Geo Place Name  \
# 0  Nitrogen dioxide (NO2)      Flushing and Whitestone (CD7)
# 1  Nitrogen dioxide (NO2)              Upper West Side (CD7)
# 2  Nitrogen dioxide (NO2)  Rockaway and Broad Channel (CD14)
# 3  Nitrogen dioxide (NO2)      Flushing and Whitestone (CD7)
# 4  Nitrogen dioxide (NO2)      Flushing and Whitestone (CD7)
#
#            Time Period Start_Date  Data Value
# 0       Winter 2014-15 2014-12-01       23.97
# 1       Winter 2014-15 2014-12-01       27.42
# 2  Annual Average 2017 2017-01-01       12.55
# 3       Winter 2015-16 2015-12-01       22.63
# 4          Summer 2016 2016-06-01       14.00

# %%
##Time to make separate dataframes so I can examine trends more closely 
##PM2.5 examination 

#Asthma emergency department visits due to PM2.5 
#asthma_df 
asthma_df= clean_df [clean_df ["Name"] == "Asthma emergency department visits due to PM2.5"] 

#Deaths due to PM2.5 
#death_df 
death_df= clean_df [clean_df ["Name"] == "Deaths due to PM2.5"] 

#Fine particles (PM 2.5) 
#pm_df 
pm_df= clean_df [clean_df["Name"] == "Fine particles (PM 2.5)"] 

#Cardiovascular hospitalizations due to PM2.5 (age 40+) 
#cardio_df 
cardio_df= clean_df [clean_df ["Name"] == "Cardiovascular hospitalizations due to PM2.5 (age 40+)"] 

#Respiratory hospitalizations due to PM2.5 (age 20+) 
#resp_df 
resp_df= clean_df [clean_df ["Name"] == "Respiratory hospitalizations due to PM2.5 (age 20+)"] 

#pm25_all 
pm25_all= clean_df [clean_df ["Name"].isin(["Respiratory hospitalizations due to PM2.5 (age 20+)","Cardiovascular hospitalizations due to PM2.5 (age 40+)","Fine particles (PM 2.5)","Deaths due to PM2.5", "Asthma emergency department visits due to PM2.5"])]

# %%
#use df.describe() as needed

#asthma_df.describe() 
#cardio_df.describe() 
#death_df.describe() 
#pm_df.describe() 
#resp_df.describe()

# %%
#Use this to check possible outliers 
#asthma_df[asthma_df['Data Value'] > 250].sort_values(by='Geo Place Name')
#cardio_df[cardio_df['Data Value'] > 30].sort_values(by='Geo Place Name')
#death_df[death_df['Data Value'] > 75].sort_values(by='Geo Place Name')
#pm_df[pm_df['Data Value'] > 15.5].sort_values(by='Geo Place Name')
#resp_df[resp_df['Data Value'] > 20].sort_values(by='Geo Place Name')

# %%
#Compare # of entries of certain variables with other variables 
pd.crosstab(pm25_all 
['Name' 
], pm25_all  
['Geo Place Name' 
])
# Out:
# Geo Place Name                                      Bay Ridge and Dyker Heights (CD10)  \
# Name
# Asthma emergency department visits due to PM2.5                                      0
# Cardiovascular hospitalizations due to PM2.5 (a...                                   0
# Deaths due to PM2.5                                                                  0
# Fine particles (PM 2.5)                                                             45
# Respiratory hospitalizations due to PM2.5 (age ...                                   0
#
# Geo Place Name                                      Bayside - Little Neck  \
# Name
# Asthma emergency department visits due to PM2.5                        10
# Cardiovascular hospitalizations due to PM2.5 (a...                      5
# Deaths due to PM2.5                                                     5
# Fine particles (PM 2.5)                                                45
# Respiratory hospitalizations due to PM2.5 (age ...                      5
#
# Geo Place Name                                      Bayside Little Neck-Fresh Meadows  \
# Name
# Asthma emergency department visits due to PM2.5                                     0
# Cardiovascular hospitalizations due to PM2.5 (a...                                  0
# Deaths due to PM2.5                                                                 0
# Fine particles (PM 2.5)                                                            45
# Respiratory hospitalizations due to PM2.5 (age ...                                  0
#
# Geo Place Name                                      Bayside and Little Neck (CD11)  \
# Name
# Asthma emergency department visits due to PM2.5                                  0
# Cardiovascular hospitalizations due to PM2.5 (a...                               0
# Deaths due to PM2.5                                                              0
# Fine particles (PM 2.5)                                                         45
# Respiratory hospitalizations due to PM2.5 (age ...                               0
#
# Geo Place Name                                      Bedford Stuyvesant (CD3)  \
# Name
# Asthma emergency department visits due to PM2.5                            0
# Cardiovascular hospitalizations due to PM2.5 (a...                         0
# Deaths due to PM2.5                                                        0
# Fine particles (PM 2.5)                                                   45
# Respiratory hospitalizations due to PM2.5 (age ...                         0
#
# Geo Place Name                                      Bedford Stuyvesant - Crown Heights  \
# Name
# Asthma emergency department visits due to PM2.5                                     10
# Cardiovascular hospitalizations due to PM2.5 (a...                                   5
# Deaths due to PM2.5                                                                  5
# Fine particles (PM 2.5)                                                             45
# Respiratory hospitalizations due to PM2.5 (age ...                                   5
#
# Geo Place Name                                      Belmont and East Tremont (CD6)  \
# Name
# Asthma emergency department visits due to PM2.5                                  0
# Cardiovascular hospitalizations due to PM2.5 (a...                               0
# Deaths due to PM2.5                                                              0
# Fine particles (PM 2.5)                                                         45
# Respiratory hospitalizations due to PM2.5 (age ...                               0
#
# Geo Place Name                                      Bensonhurst (CD11)  \
# Name
# Asthma emergency department visits due to PM2.5                      0
# Cardiovascular hospitalizations due to PM2.5 (a...                   0
# Deaths due to PM2.5                                                  0
# Fine particles (PM 2.5)                                             45
# Respiratory hospitalizations due to PM2.5 (age ...                   0
#
# Geo Place Name                                      Bensonhurst - Bay Ridge  \
# Name
# Asthma emergency department visits due to PM2.5                          10
# Cardiovascular hospitalizations due to PM2.5 (a...                        5
# Deaths due to PM2.5                                                       5
# Fine particles (PM 2.5)                                                  45
# Respiratory hospitalizations due to PM2.5 (age ...                        5
#
# Geo Place Name                                      Borough Park  ...  \
# Name                                                              ...
# Asthma emergency department visits due to PM2.5               10  ...
# Cardiovascular hospitalizations due to PM2.5 (a...             5  ...
# Deaths due to PM2.5                                            5  ...
# Fine particles (PM 2.5)                                       45  ...
# Respiratory hospitalizations due to PM2.5 (age ...             5  ...
#
# Geo Place Name                                      Upper East Side-Gramercy  \
# Name
# Asthma emergency department visits due to PM2.5                            0
# Cardiovascular hospitalizations due to PM2.5 (a...                         0
# Deaths due to PM2.5                                                        0
# Fine particles (PM 2.5)                                                   45
# Respiratory hospitalizations due to PM2.5 (age ...                         0
#
# Geo Place Name                                      Upper West Side  \
# Name
# Asthma emergency department visits due to PM2.5                  10
# Cardiovascular hospitalizations due to PM2.5 (a...                5
# Deaths due to PM2.5                                               5
# Fine particles (PM 2.5)                                          54
# Respiratory hospitalizations due to PM2.5 (age ...                5
#
# Geo Place Name                                      Upper West Side (CD7)  \
# Name
# Asthma emergency department visits due to PM2.5                         0
# Cardiovascular hospitalizations due to PM2.5 (a...                      0
# Deaths due to PM2.5                                                     0
# Fine particles (PM 2.5)                                                45
# Respiratory hospitalizations due to PM2.5 (age ...                      0
#
# Geo Place Name                                      Washington Heights  \
# Name
# Asthma emergency department visits due to PM2.5                     10
# Cardiovascular hospitalizations due to PM2.5 (a...                   5
# Deaths due to PM2.5                                                  5
# Fine particles (PM 2.5)                                             66
# Respiratory hospitalizations due to PM2.5 (age ...                   5
#
# Geo Place Name                                      Washington Heights and Inwood (CD12)  \
# Name
# Asthma emergency department visits due to PM2.5                                        0
# Cardiovascular hospitalizations due to PM2.5 (a...                                     0
# Deaths due to PM2.5                                                                    0
# Fine particles (PM 2.5)                                                               45
# Respiratory hospitalizations due to PM2.5 (age ...                                     0
#
# Geo Place Name                                      West Queens  \
# Name
# Asthma emergency department visits due to PM2.5              10
# Cardiovascular hospitalizations due to PM2.5 (a...            5
# Deaths due to PM2.5                                           5
# Fine particles (PM 2.5)                                      46
# Respiratory hospitalizations due to PM2.5 (age ...            5
#
# Geo Place Name                                      Williamsbridge and Baychester (CD12)  \
# Name
# Asthma emergency department visits due to PM2.5                                        0
# Cardiovascular hospitalizations due to PM2.5 (a...                                     0
# Deaths due to PM2.5                                                                    0
# Fine particles (PM 2.5)                                                               45
# Respiratory hospitalizations due to PM2.5 (age ...                                     0
#
# Geo Place Name                                      Williamsburg - Bushwick  \
# Name
# Asthma emergency department visits due to PM2.5                          10
# Cardiovascular hospitalizations due to PM2.5 (a...                        5
# Deaths due to PM2.5                                                       5
# Fine particles (PM 2.5)                                                  57
# Respiratory hospitalizations due to PM2.5 (age ...                        5
#
# Geo Place Name                                      Willowbrook  \
# Name
# Asthma emergency department visits due to PM2.5              10
# Cardiovascular hospitalizations due to PM2.5 (a...            5
# Deaths due to PM2.5                                           5
# Fine particles (PM 2.5)                                      45
# Respiratory hospitalizations due to PM2.5 (age ...            5
#
# Geo Place Name                                      Woodside and Sunnyside (CD2)
# Name
# Asthma emergency department visits due to PM2.5                                0
# Cardiovascular hospitalizations due to PM2.5 (a...                             0
# Deaths due to PM2.5                                                            0
# Fine particles (PM 2.5)                                                       45
# Respiratory hospitalizations due to PM2.5 (age ...                             0
#
# [5 rows x 114 columns]

# %%
#examine specific regions 
bayside_little_neck= pm25_all [pm25_all ['Geo Place Name'].isin(['Bayside - Little Neck'])].sort_values(by='Time Period')
little_neck=bayside_little_neck.style.set_caption("Bayside - Little Neck") 
little_neck
# Out:
# <style type="text/css">
# </style>
# <table id="T_28782">
#   <caption>Bayside - Little Neck</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28782_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_28782_level0_col1" class="col_heading level0 col1" >Geo Place Name</th>
#       <th id="T_28782_level0_col2" class="col_heading level0 col2" >Time Period</th>
#       <th id="T_28782_level0_col3" class="col_heading level0 col3" >Start_Date</th>
#       <th id="T_28782_level0_col4" class="col_heading level0 col4" >Data Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28782_level0_row0" class="row_heading level0 row0" >5728</th>
#       <td id="T_28782_row0_col0" class="data row0 col0" >Respiratory hospitalizations due to PM2.5 (age 20+)</td>
#       <td id="T_28782_row0_col1" class="data row0 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row0_col2" class="data row0 col2" >2005-2007</td>
#       <td id="T_28782_row0_col3" class="data row0 col3" >2005-01-01 00:00:00</td>
#       <td id="T_28782_row0_col4" class="data row0 col4" >15.100000</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row1" class="row_heading level0 row1" >18743</th>
#       <td id="T_28782_row1_col0" class="data row1 col0" >Deaths due to PM2.5</td>
#       <td id="T_28782_row1_col1" class="data row1 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row1_col2" class="data row1 col2" >2005-2007</td>
#       <td id="T_28782_row1_col3" class="data row1 col3" >2005-01-01 00:00:00</td>
#       <td id="T_28782_row1_col4" class="data row1 col4" >48.900000</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row2" class="row_heading level0 row2" >18459</th>
#       <td id="T_28782_row2_col0" class="data row2 col0" >Cardiovascular hospitalizations due to PM2.5 (age 40+)</td>
#       <td id="T_28782_row2_col1" class="data row2 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row2_col2" class="data row2 col2" >2005-2007</td>
#       <td id="T_28782_row2_col3" class="data row2 col3" >2005-01-01 00:00:00</td>
#       <td id="T_28782_row2_col4" class="data row2 col4" >18.300000</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row3" class="row_heading level0 row3" >11463</th>
#       <td id="T_28782_row3_col0" class="data row3 col0" >Asthma emergency department visits due to PM2.5</td>
#       <td id="T_28782_row3_col1" class="data row3 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row3_col2" class="data row3 col2" >2005-2007</td>
#       <td id="T_28782_row3_col3" class="data row3 col3" >2005-01-01 00:00:00</td>
#       <td id="T_28782_row3_col4" class="data row3 col4" >26.700000</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row4" class="row_heading level0 row4" >11732</th>
#       <td id="T_28782_row4_col0" class="data row4 col0" >Asthma emergency department visits due to PM2.5</td>
#       <td id="T_28782_row4_col1" class="data row4 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row4_col2" class="data row4 col2" >2005-2007</td>
#       <td id="T_28782_row4_col3" class="data row4 col3" >2005-01-01 00:00:00</td>
#       <td id="T_28782_row4_col4" class="data row4 col4" >8.500000</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row5" class="row_heading level0 row5" >10371</th>
#       <td id="T_28782_row5_col0" class="data row5 col0" >Asthma emergency department visits due to PM2.5</td>
#       <td id="T_28782_row5_col1" class="data row5 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row5_col2" class="data row5 col2" >2009-2011</td>
#       <td id="T_28782_row5_col3" class="data row5 col3" >2009-01-01 00:00:00</td>
#       <td id="T_28782_row5_col4" class="data row5 col4" >6.700000</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row6" class="row_heading level0 row6" >5727</th>
#       <td id="T_28782_row6_col0" class="data row6 col0" >Respiratory hospitalizations due to PM2.5 (age 20+)</td>
#       <td id="T_28782_row6_col1" class="data row6 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row6_col2" class="data row6 col2" >2009-2011</td>
#       <td id="T_28782_row6_col3" class="data row6 col3" >2009-01-01 00:00:00</td>
#       <td id="T_28782_row6_col4" class="data row6 col4" >10.200000</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row7" class="row_heading level0 row7" >14130</th>
#       <td id="T_28782_row7_col0" class="data row7 col0" >Cardiovascular hospitalizations due to PM2.5 (age 40+)</td>
#       <td id="T_28782_row7_col1" class="data row7 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row7_col2" class="data row7 col2" >2009-2011</td>
#       <td id="T_28782_row7_col3" class="data row7 col3" >2009-01-01 00:00:00</td>
#       <td id="T_28782_row7_col4" class="data row7 col4" >12.500000</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row8" class="row_heading level0 row8" >13738</th>
#       <td id="T_28782_row8_col0" class="data row8 col0" >Asthma emergency department visits due to PM2.5</td>
#       <td id="T_28782_row8_col1" class="data row8 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row8_col2" class="data row8 col2" >2009-2011</td>
#       <td id="T_28782_row8_col3" class="data row8 col3" >2009-01-01 00:00:00</td>
#       <td id="T_28782_row8_col4" class="data row8 col4" >22.100000</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row9" class="row_heading level0 row9" >14095</th>
#       <td id="T_28782_row9_col0" class="data row9 col0" >Deaths due to PM2.5</td>
#       <td id="T_28782_row9_col1" class="data row9 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row9_col2" class="data row9 col2" >2009-2011</td>
#       <td id="T_28782_row9_col3" class="data row9 col3" >2009-01-01 00:00:00</td>
#       <td id="T_28782_row9_col4" class="data row9 col4" >34.500000</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row10" class="row_heading level0 row10" >15559</th>
#       <td id="T_28782_row10_col0" class="data row10 col0" >Asthma emergency department visits due to PM2.5</td>
#       <td id="T_28782_row10_col1" class="data row10 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row10_col2" class="data row10 col2" >2012-2014</td>
#       <td id="T_28782_row10_col3" class="data row10 col3" >2012-01-02 00:00:00</td>
#       <td id="T_28782_row10_col4" class="data row10 col4" >6.627942</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row11" class="row_heading level0 row11" >8650</th>
#       <td id="T_28782_row11_col0" class="data row11 col0" >Respiratory hospitalizations due to PM2.5 (age 20+)</td>
#       <td id="T_28782_row11_col1" class="data row11 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row11_col2" class="data row11 col2" >2012-2014</td>
#       <td id="T_28782_row11_col3" class="data row11 col3" >2012-01-02 00:00:00</td>
#       <td id="T_28782_row11_col4" class="data row11 col4" >6.965867</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row12" class="row_heading level0 row12" >15934</th>
#       <td id="T_28782_row12_col0" class="data row12 col0" >Cardiovascular hospitalizations due to PM2.5 (age 40+)</td>
#       <td id="T_28782_row12_col1" class="data row12 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row12_col2" class="data row12 col2" >2012-2014</td>
#       <td id="T_28782_row12_col3" class="data row12 col3" >2012-01-02 00:00:00</td>
#       <td id="T_28782_row12_col4" class="data row12 col4" >8.655824</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row13" class="row_heading level0 row13" >18711</th>
#       <td id="T_28782_row13_col0" class="data row13 col0" >Deaths due to PM2.5</td>
#       <td id="T_28782_row13_col1" class="data row13 col1" >Bayside - Little Neck</td>
#       <td id="T_28782_row13_col2" class="data row13 col2" >2012-2014</td>
#       <td id="T_28782_row13_col3" class="data row13 col3" >2012-01-02 00:00:00</td>
#       <td id="T_28782_row13_col4" class="data row13 col4" >28.434109</td>
#     </tr>
#     <tr>
#       <th id="T_28782_level0_row14" class="row_heading level0 row14" >8629</th>
#       <td id="T_28782_row14_col0" class="data row14 col0" >A

# %%
#make histogram to check for outliers 
#y axis is value counts, x is Data Value 
pm25_all.hist(column='Data Value', by='Name', bins=5, edgecolor='black', figsize=(10, 18), layout=(9,2))  
plt.suptitle("Data Values by Type", y=1.02)  
plt.subplots_adjust(hspace=0.8, wspace=0.4) 
plt.tight_layout() 
plt.show()

# %%
#pivot table
asthma_pivot = asthma_df.pivot_table( index=['Geo Place Name', 'Time Period'], columns='Name', values='Data Value' ) 
asthma_pivot.columns = asthma_pivot.columns.str.strip() 
asthma_pivot
# Out:
# Name                               Asthma emergency department visits due to PM2.5
# Geo Place Name        Time Period
# Bayside - Little Neck 2005-2007                                          17.600000
#                       2009-2011                                          14.400000
#                       2012-2014                                          10.031533
#                       2015-2017                                           8.550000
#                       2017-2019                                           6.000000
# ...                                                                            ...
# Willowbrook           2005-2007                                          23.200000
#                       2009-2011                                          24.400000
#                       2012-2014                                          21.323009
#                       2015-2017                                          15.850000
#                       2017-2019                                          14.000000
#
# [240 rows x 1 columns]

# %%
#whisker box plot 

plt.figure(figsize=(6, 2)) 
sns.boxplot(data=asthma_df, x='Data Value', linewidth=0.9) 
plt.show()

# %%
sns.scatterplot(data = asthma_df, x = 'Data Value', 
                y = 'Time Period');

# %%
#correlation calculation without visuals
correlation_value = asthma_df['Data Value'].corr(pm25_all['Data Value'])
print(correlation_value
# Out:
#   File "C:\Users\Administrator\AppData\Local\Temp\ipykernel_3596\3380819590.py", line 3
#     print(correlation_value
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
#scatter plot - asthma ER vs pm2.5 levels
#will use these dfs later too
asthma_df2 = asthma_df.rename(columns={"Data Value": "asthma_er_visits"})  
pm_df2 = pm_df.rename(columns={"Data Value": "pm25_levels"})  

merged_df = pd.merge(asthma_df2, pm_df2, on="Geo Place Name")  
plt.figure(figsize=(8, 6)) 
sns.scatterplot(data=merged_df, x="pm25_levels", y="asthma_er_visits") 

plt.title("PM2.5 Levels vs. Asthma ER Visits")  
plt.xlabel("PM2.5 Concentration") 
plt.ylabel("Asthma ER Visits")  
plt.grid(True, linestyle="--", alpha=0.2)  
plt.show()

# %%
#clean it up so it's readable - though a heat map may be better
sns.regplot(data=merged_df, x='pm25_levels', y='asthma_er_visits', 
            scatter_kws={'alpha': 0.1}, line_kws={'color': 'red'}, lowess=True)
plt.title('Trend Analysis: PM2.5 Levels vs. Asthma ER Visits')
plt.show()

# %%
#look at trends over the years
asthma = asthma_df['Start_Date'].dt.year 
sns.lineplot(data = asthma_df, x = "Start_Date", 
       y = 'Data Value', 
       estimator = np.mean);

# %%
#heat map 1

asthma_df2 = asthma_df.rename(columns={"Data Value": "asthma_er_visits"})  
pm_df2 = pm_df.rename(columns={"Data Value": "pm25_levels"})  
cardio_df2=cardio_df.rename(columns={"Data Value": "cardio_levels"})  
death_df2=death_df.rename(columns={"Data Value": "death_levels"})  
resp_df2= resp_df.rename(columns={"Data Value": "resp_levels"})  

merged_df = (
    asthma_df2
    .merge(pm_df2, on="Geo Place Name")
    .merge(cardio_df2, on="Geo Place Name")
    .merge(death_df2, on="Geo Place Name")
    .merge(resp_df2, on="Geo Place Name")
)



columns_to_correlate = ['asthma_er_visits', 'pm25_levels', 'cardio_levels', 'death_levels', 'resp_levels']
corr_matrix = merged_df[columns_to_correlate].corr()

plt.figure(figsize=(11, 8))
sns.heatmap(
    corr_matrix,        
    cmap='seismic',
    linewidths=0.75,       
    linecolor='black',
    cbar=True,
    vmin=-1,
    vmax=1,
    annot=True,
    annot_kws={'size': 8, 'color': 'black'}
)
annot_kws = {'size': 8, 'color': 'black'} 

plt.tick_params(labelsize = 10, rotation = 45) 
plt.title('Correlation Plot', size = 14); 
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3596\3132930149.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Time Period_x', 'Start_Date_x', 'Name_x'} in the result is deprecated and will raise a MergeError in a future version.
#   asthma_df2

# %%
unique_variables = air_df['Name'].unique()
print(unique_variables)
# Out:
# ['Nitrogen dioxide (NO2)' 'Fine particles (PM 2.5)'
#  'Boiler Emissions- Total SO2 Emissions' 'Ozone (O3)'
#  'Asthma emergency department visits due to PM2.5'
#  'Annual vehicle miles traveled'
#  'Respiratory hospitalizations due to PM2.5 (age 20+)'
#  'Asthma hospitalizations due to Ozone'
#  'Boiler Emissions- Total NOx Emissions'
#  'Boiler Emissions- Total PM2.5 Emissions'
#  'Outdoor Air Toxics - Formaldehyde' 'Outdoor Air Toxics - Benzene'
#  'Asthma emergency departments visits due to Ozone'
#  'Annual vehicle miles traveled (cars)'
#  'Annual vehicle miles traveled (trucks)'
#  'Cardiovascular hospitalizations due to PM2.5 (age 40+)'
#  'Deaths due to PM2.5' 'Cardiac and respiratory deaths due to Ozone']

# %%
#Environmental Pollutants 
no2_df = clean_df[clean_df["Name"] == "Nitrogen dioxide (NO2)"] 
pm25_df = clean_df[clean_df["Name"] == "Fine particles (PM 2.5)"] 
ozone_df = clean_df[clean_df["Name"] == "Ozone (O3)"] 

#Boiler & Industrial Emissions 
so2_em_df = clean_df[clean_df["Name"] == "Boiler Emissions- Total SO2 Emissions"] 
nox_em_df = clean_df[clean_df["Name"] == "Boiler Emissions- Total NOx Emissions"] 
pm25_em_df = clean_df[clean_df["Name"] == "Boiler Emissions- Total PM2.5 Emissions"] 

#Outdoor Air Toxics 
form_df = clean_df[clean_df["Name"] == "Outdoor Air Toxics - Formaldehyde"] 
benz_df = clean_df[clean_df["Name"] == "Outdoor Air Toxics - Benzene"] 

#Traffic & Vehicle Metrics 
vmt_df = clean_df[clean_df["Name"] == "Annual vehicle miles traveled"] 
vmt_cars_df = clean_df[clean_df["Name"] == "Annual vehicle miles traveled (cars)"] 
vmt_trck_df = clean_df[clean_df["Name"] == "Annual vehicle miles traveled (trucks)"] 

#Health: Asthma 
asth_pm_df = clean_df[clean_df["Name"] == "Asthma emergency department visits due to PM2.5"] 
asth_oz_h_df= clean_df[clean_df["Name"] == "Asthma hospitalizations due to Ozone"] 
asth_oz_ed_df= clean_df[clean_df["Name"] == "Asthma emergency departments visits due to Ozone"] 

#Health: everything else
resp_df = clean_df[clean_df["Name"] == "Respiratory hospitalizations due to PM2.5 (age 20+)"] 
cardio_df = clean_df[clean_df["Name"] == "Cardiovascular hospitalizations due to PM2.5 (age 40+)"] 
deaths_pm_df= clean_df[clean_df["Name"] == "Deaths due to PM2.5"] 
deaths_oz_df= clean_df[clean_df["Name"] == "Cardiac and respiratory deaths due to Ozone"]

# %%
pivoted_df = clean_df.pivot_table( index="Geo Place Name", columns="Name", values="Data Value", aggfunc="mean" ) 

name_mapping = { 'Nitrogen dioxide (NO2)': 'NO2 Levels', 'Fine particles (PM 2.5)': 'PM2.5 Levels', 'Boiler Emissions- Total SO2 Emissions': 'Boiler SO2', 'Ozone (O3)': 'Ozone Levels', 'Asthma emergency department visits due to PM2.5': 'Asthma ED (PM2.5)', 'Annual vehicle miles traveled': 'VMT Total', 'Respiratory hospitalizations due to PM2.5 (age 20+)': 'Resp Hosp (PM2.5)', 'Asthma hospitalizations due to Ozone': 'Asthma Hosp (Ozone)', 'Boiler Emissions- Total NOx Emissions': 'Boiler NOx', 'Boiler Emissions- Total PM2.5 Emissions': 'Boiler PM2.5', 'Outdoor Air Toxics - Formaldehyde': 'Formaldehyde', 'Outdoor Air Toxics - Benzene': 'Benzene', 'Asthma emergency departments visits due to Ozone': 'Asthma ED (Ozone)', 'Annual vehicle miles traveled (cars)': 'VMT Cars', 'Annual vehicle miles traveled (trucks)': 'VMT Trucks', 'Cardiovascular hospitalizations due to PM2.5 (age 40+)': 'Cardio Hosp (PM2.5)', 'Deaths due to PM2.5': 'Deaths (PM2.5)', 'Cardiac and respiratory deaths due to Ozone': 'Deaths (Ozone)' } 
pivoted_df = pivoted_df.rename(columns=name_mapping)

# %%
# heat map of envronmental & health variables
corr_matrix = pivoted_df.corr() 
mask = np.triu(np.ones_like(corr_matrix, dtype=bool)) 
plt.figure(figsize=(16, 12)) 
sns.heatmap( corr_matrix, mask=mask, cmap='seismic', linewidths=0.5, linecolor='black', cbar=True, vmin=-1, vmax=1, annot=True, fmt=".2f", annot_kws={'size': 8, 'color': 'black'} ) 
plt.xticks(rotation=45, ha='right', fontsize=9) 
plt.yticks(rotation=0, fontsize=9) 
plt.title('Comprehensive Environmental Health Correlation Matrix', size=16, pad=20) 
plt.tight_layout() 
plt.show()

# %%
clean_df['Name'] = clean_df['Name'].astype(str).str.strip()

target_labels = [
"Nitrogen dioxide (NO2)",
"Fine particles (PM 2.5)",
"Boiler Emissions- Total SO2 Emissions",
"Ozone (O3)",
"Boiler Emissions- Total NOx Emissions",
"Boiler Emissions- Total PM2.5 Emissions",
"Outdoor Air Toxics - Formaldehyde",
"Outdoor Air Toxics - Benzene",
"Annual vehicle miles traveled (cars)",
"Annual vehicle miles traveled (trucks)"]

neigh_df = clean_df[clean_df["Name"].isin(target_labels)]

# %%
print(target_labels.(describe))
# Out:
#   File "C:\Users\Administrator\AppData\Local\Temp\ipykernel_3596\1425082861.py", line 1
#     print(target_labels.(describe))
#                         ^
# SyntaxError: invalid syntax

# %%
# heat map
neigh_matrix = neigh_df.pivot_table(index="Geo Place Name", columns="Name", values="Data Value")
mask = neigh_matrix.isnull()
plt.figure(figsize=(14, 80)) 
sns.heatmap(neigh_matrix, mask=mask, cmap='seismic', linewidths=0.5, linecolor='black', vmin=-1, vmax=20, cbar=False, annot=True, fmt=".2f", annot_kws={'size': 9, 'color': 'black'} ) 
plt.xticks(rotation=45, ha='right', fontsize=9) 
plt.yticks(rotation=0, fontsize=9) 
plt.title('Environmental Health by Location Matrix', size=16, pad=20) 
plt.tight_layout() 
plt.show()

# %%
#look at trends over the years
asthma = asthma_df['Start_Date'].dt.year 
sns.lineplot(data = asthma_df, x = "Start_Date", 
       y = 'Data Value', 
       estimator = np.mean);
